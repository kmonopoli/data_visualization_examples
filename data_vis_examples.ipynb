# %% [markdown]
# # Data Visualization Examples

# %% [markdown]
# <a id='top'></a>
# # Contents:
# * [Various Example Plots](#plots)
# * [Color Schemes](#color_schemes)
# * [Gene Diagram](#gene_diagram)
# * [Interactive Plots](#int_plts)
#     * [D3](#d3)
#     * [Tableau](#Tableau)
#
# * [Additional Useful Methods](#etc)

# %% [markdown]
# <a id='plots'></a>
# # Various Plot Types

# %% [markdown]
# ## Bar
# Use to:
# * compare different categories
# * compare parts of a whole
# * show change over time

# %%
# import required packages
from matplotlib import cm
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline  
# Bar plot 1
# import required packages (the term library/package mean the same thing and are used interchangably throughout)
import matplotlib # general library for plotting (developed based off of Matlab)
import matplotlib.pyplot as plt 
import pandas as pd # library for data manipulation, allows making dataframe similar to those in R

# set font 
font = {
        'sans-serif':'Arial',
        'size'   : 15}
matplotlib.rc('font', **font)

# set figure size
figure = {'figsize':[6.0, 4.0]}
matplotlib.rc('figure', **figure)

# set figure color scheme
axes = {'prop_cycle': matplotlib.cycler('color',["#003f5c",'#d45087','#ffa600'])}
matplotlib.rc('axes', **axes)


# data to plot 
df = pd.read_csv("immunotherapy_tx1.csv") # read in data from file 
# reshape data put in format for plotting
counts = df.groupby('sex').count().iloc[:, 0]
labels = ["Female","Male"]
width = 0.6 # bar width

# plot data
plt.figure() 
plt.barh(labels,counts,width) # code to make the plot
plt.xlabel("Sex") # x-axis labe
plt.ylabel("Count") # y-axis label
plt.title("Gender of Patients Treated",pad=20, fontsize = 15) # title
plt.tight_layout() 

# plt.savefig('min_df_vs_accuracy.eps',bbox_inches="tight",transparent=True)

# %%
# Bar plot 2
# import required packages
import matplotlib # general library for plotting (developed based off of Matlab)
import matplotlib.pyplot as plt 
import pandas as pd # library for data manipulation, allows making dataframe similar to those in R

# set font 
font = {
        'sans-serif':'Arial',
        'size'   : 15}
matplotlib.rc('font', **font)

# set figure size
figure = {'figsize':[6.0, 6.0]}
matplotlib.rc('figure', **figure)

# set figure color scheme
axes = {'prop_cycle': matplotlib.cycler('color',["#00A08A", "#F2AD00", "#F98400", "#5BBCD6"])}
matplotlib.rc('axes', **axes)


# data to plot 
df = pd.read_csv("immunotherapy_tx1.csv") # read in data from file
# reshape data put in format for plotting

fail = list(df[df["Result_of_Treatment"]==1].groupby('sex').count().iloc[:, 0])
success = list(df[df["Result_of_Treatment"]==1].groupby('sex').count().iloc[:, 0])
labels = ["Female","Male"]

# plot data
plt.figure() 
p1 = plt.bar(labels, fail) # code to make the top plot
p2 = plt.bar(labels, success, bottom=fail) # code to make the bottom plot
plt.legend((p1[0], p2[0]), ('Fail', 'Success')) # add legend
plt.xlabel("Sex") # x-axis labe
plt.ylabel("Count") # y-axis label
plt.title("Treatment Outcome by Gender",pad=20) # title
plt.tight_layout() 

# # plt.savefig('min_df_vs_accuracy.eps',bbox_inches="tight",transparent=True)

# %% [markdown]
# ## Box and Whisker
# * 1-dimmensional data
# * show distribution of data
# * identify outliers

# %%
# Box and Whisker
# import required packages
import matplotlib # general library for plotting (developed based off of Matlab)
import matplotlib.pyplot as plt 
import pandas as pd # library for data manipulation, allows making dataframe similar to those in R

# set font 
font = {
        'sans-serif':'Arial',
        'size'   : 15}
matplotlib.rc('font', **font)

# set figure size
figure = {'figsize':[8.0, 4.0]}
matplotlib.rc('figure', **figure)


# data to plot 
df = pd.read_csv("immunotherapy_tx1.csv") # read in data from file
df.rename(columns={"Number_of_Warts": "Number of Warts"},inplace=True) # Rename a single column

# plot data
# Here using the Seaborn Package (similar to R's ggplot)
#    It does a lot of the work for you to plot (but can make it challenging to customize the figures) 
#    Notice here that we plot directly from the dataframe without making a list
# import seaborn package
import seaborn as sns
# code to generate the boxplot
# notice we add a color parameter, you could do the same above, if you have more than one variable you need to provide a list of colors
ax = sns.boxplot(x=df["Number of Warts"],orient="horizontal", color = "#5BBCD6") 
# since we are plotting with Seaborn we have to get the figure before we can save it
fig = ax.get_figure()
fig.tight_layout() 

fig.savefig('wart_number_distribution.eps',bbox_inches="tight",transparent=True)

# %% [markdown]
# ## Histogram
# * 1-dimmensional data
# * show distribution of data
# * identify outliers

# %%
# Histogram
# import required packages (the term library/package mean the same thing and are used interchangably throughout)
import matplotlib # general library for plotting (developed based off of Matlab)
import matplotlib.pyplot as plt 
import pandas as pd # library for data manipulation, allows making dataframe similar to those in R

# set font 
font = {
        'sans-serif':'Arial',
        'size'   : 15}
matplotlib.rc('font', **font)

# set figure size
figure = {'figsize':[6.0, 4.0]}
matplotlib.rc('figure', **figure)

# set figure color scheme
axes = {'prop_cycle': matplotlib.cycler('color',["#003f5c",'#d45087','#ffa600'])}
matplotlib.rc('axes', **axes)


# data to plot 
df = pd.read_csv("immunotherapy_tx1.csv") # read in data from file 

# plot data
plt.figure() 
plt.hist(df.Number_of_Warts) # code to make the plot
plt.xlabel("Number of Warts") # x-axis labe
plt.ylabel("Count") # y-axis label
plt.tight_layout() 

# plt.savefig('min_df_vs_accuracy.eps',bbox_inches="tight",transparent=True)

# %% [markdown]
# ## Probability Distribution

# %%
# Probability Distribution
# import required packages (the term library/package mean the same thing and are used interchangably throughout)
import matplotlib # general library for plotting (developed based off of Matlab)
import matplotlib.pyplot as plt 
import pandas as pd # library for data manipulation, allows making dataframe similar to those in R

# set font 
font = {
        'sans-serif':'Arial',
        'size'   : 15}
matplotlib.rc('font', **font)

# set figure size
figure = {'figsize':[6.0, 4.0]}
matplotlib.rc('figure', **figure)

# set figure color scheme
axes = {'prop_cycle': matplotlib.cycler('color',["#003f5c",'#d45087','#ffa600'])}
matplotlib.rc('axes', **axes)


# data to plot 
df = pd.read_csv("immunotherapy_tx1.csv") # read in data from file 

# plot data
plt.figure() 
plt.hist(df.Number_of_Warts, density=True) # code to make the plot, just add density=True parameter to make it a PDF
plt.xlabel("Number of Warts") # x-axis labe
plt.ylabel("Count") # y-axis label
plt.tight_layout()

# %% [markdown]
# ## Cummulative Distribution

# %%
# Probability Distribution
# import required packages (the term library/package mean the same thing and are used interchangably throughout)
import matplotlib # general library for plotting (developed based off of Matlab)
import matplotlib.pyplot as plt 
import pandas as pd # library for data manipulation, allows making dataframe similar to those in R

# set font 
font = {
        'sans-serif':'Arial',
        'size'   : 15}
matplotlib.rc('font', **font)

# set figure size
figure = {'figsize':[6.0, 4.0]}
matplotlib.rc('figure', **figure)

# set figure color scheme
axes = {'prop_cycle': matplotlib.cycler('color',["#003f5c",'#d45087','#ffa600'])}
matplotlib.rc('axes', **axes)


# data to plot 
df = pd.read_csv("immunotherapy_tx1.csv") # read in data from file 

# plot data
plt.figure() 
plt.hist(df.Number_of_Warts, density=True,cumulative=1) # code to make the plot, just add density=True parameter and the cumulative=1 parameter to make it a CDF
plt.xlabel("Number of Warts") # x-axis labe
plt.ylabel("Count") # y-axis label
plt.tight_layout()

# %% [markdown]
# ## Density plot

# %%
# Density
# import required packages (the term library/package mean the same thing and are used interchangably throughout)
import matplotlib # general library for plotting (developed based off of Matlab)
import matplotlib.pyplot as plt 
import pandas as pd # library for data manipulation, allows making dataframe similar to those in R
import seaborn as sns
# set font 
font = {
        'sans-serif':'Arial',
        'size'   : 15}
matplotlib.rc('font', **font)

# set figure size
figure = {'figsize':[6.0, 4.0]}
matplotlib.rc('figure', **figure)

# set figure color scheme
axes = {'prop_cycle': matplotlib.cycler('color',["#003f5c",'#d45087','#ffa600'])}
matplotlib.rc('axes', **axes)


# data to plot 
df = pd.read_csv("immunotherapy_tx1.csv") # read in data from file 

# plot data
plt.figure() 
sns.distplot(df.Number_of_Warts,  kde=True,hist=False, kde_kws = {'shade': True, 'linewidth': 3}) 
plt.xlabel("Number of Warts") # x-axis labe
plt.ylabel("Count") # y-axis label
plt.tight_layout()

# %% [markdown]
# ## Violin Plot
# * 1-dimmensional data
# * show distribution of data - good for larger datasets
# * identify outliers

# %%
# Violin Plot
# import required packages
import matplotlib # general library for plotting (developed based off of Matlab)
import matplotlib.pyplot as plt 
import pandas as pd # library for data manipulation, allows making dataframe similar to those in R
import numpy as np # library for matrix manipulation, used here for generating random numbers

# set font 
font = {
        'sans-serif':'Arial',
        'size'   : 15}
matplotlib.rc('font', **font)

# set figure size
figure = {'figsize':[6.0, 6.0]}
matplotlib.rc('figure', **figure)

# set figure color scheme
axes = {'prop_cycle': matplotlib.cycler('color',["#7b4173"])}
matplotlib.rc('axes', **axes)

# data to plot 
# here we will generate random numbers to plot
mu, sigma = 0, 0.1 # mean and standard deviation
sz = 10000 # number of data points to generate
data = np.random.normal(size=sz) # generate 1000 random values from the normal distribution

# plot data
plt.violinplot(data,showmeans=True) 
plt.tick_params(axis='x',bottom=False,labelbottom=False)

# %% [markdown]
# ## Scatter Plot
# * Display 2-dimmensional data

# %%
# import required packages
import matplotlib # general library for plotting (developed based off of Matlab)
import matplotlib.pyplot as plt 
import pandas as pd # library for data manipulation, allows making dataframe similar to those in R

# set font 
font = {
        'sans-serif':'Arial',
        'size'   : 15}
matplotlib.rc('font', **font)

# set figure size
figure = {'figsize':[6.0, 6.0]}
matplotlib.rc('figure', **figure)



# data to plot 
df = pd.read_csv("immunotherapy_tx1.csv") # read in data from file
# reshape data put in format for plotting

x = list(df.age)
y = list(df.Number_of_Warts)

# plot data
plt.figure() 
plt.scatter(x, y,color="#F2AD00") # code to make the plot
plt.xlabel("Age") # x-axis labe
plt.ylabel("Number of Warts") # y-axis label
plt.tight_layout() 

# # plt.savefig('min_df_vs_accuracy.eps',bbox_inches="tight",transparent=True)

# %%
# Scatter plot - larger dataset
# import required packages
import matplotlib # general library for plotting (developed based off of Matlab)
import matplotlib.pyplot as plt 
import pandas as pd # library for data manipulation, allows making dataframe similar to those in R
import numpy as np # library for matrix manipulation, used here for generating random numbers

# set font 
font = {
        'sans-serif':'Arial',
        'size'   : 15}
matplotlib.rc('font', **font)

# set figure size
figure = {'figsize':[6.0, 6.0]}
matplotlib.rc('figure', **figure)



# data to plot 
# here we will generate random numbers to plot
mu, sigma = 0, 0.1 # mean and standard deviation
sz = 10000 # number of data points to generate
x = np.random.normal(mu, sigma, sz) # generate 1000 random values from the normal distribution
y = np.random.exponential( size = sz) # generate 1000 random values from the exponential distribution

# plot data
#   Here we include an alpha parameter which adjusts the transparency of the point
#   This makes it easier to visualize density when there are a lot of overlapping points
plt.scatter(x, y, color = "#7b4173",alpha=0.3)
plt.xlabel("x") # x-axis label
plt.ylabel("y") # y-axis label
plt.tight_layout()

# %% [markdown]
# #### Add color and size difference to markers to show additional dimmensions of data on the same plot

# %%
# Scatter plot - larger dataset
# import required packages
import matplotlib # general library for plotting (developed based off of Matlab)
import matplotlib.pyplot as plt 
import pandas as pd # library for data manipulation, allows making dataframe similar to those in R
import numpy as np # library for matrix manipulation, used here for generating random numbers
# set font 
font = {
        'sans-serif':'Arial',
        'size'   : 15}
matplotlib.rc('font', **font)

# set figure size
figure = {'figsize':[6.0, 6.0]}
matplotlib.rc('figure', **figure)



# data to plot 
# here we will generate random numbers to plot 
rng = np.random.RandomState(0)
x = rng.randn(100) # generate 100 random values from the normal distribution
y = rng.randn(100) # generate 100 random values from the normal distribution
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

# Here we are plotting data with multiple colors so we use a colormap (cmap), which is like a type of colorscheme
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap="viridis")
plt.xlabel("x") # x-axis label
plt.ylabel("y") # y-axis label
plt.colorbar();  # show color scale

# %% [markdown]
# ## Dendrogram

# %%
# Libraries
import pandas as pd
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np
 
# Data set
url = 'https://python-graph-gallery.com/wp-content/uploads/mtcars.csv'
df = pd.read_csv(url)
df = df.set_index('model')
 
# Calculate the distance between each sample
Z = linkage(df, 'ward')
 
# Make the dendro
dendrogram(Z, labels=df.index, leaf_rotation=0, orientation="left", color_threshold=240, above_threshold_color='grey')
 
# Create a color palette with 3 color for the 3 cyl possibilities
my_palette = plt.cm.get_cmap("Accent", 3)
 
# transforme the 'cyl' column in a categorical variable. It will allow to put one color on each level.
df['cyl']=pd.Categorical(df['cyl'])
my_color=df['cyl'].cat.codes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-92bf8d646585> in <module>
#      14
#      15 # Make the dendro
# ---> 16 dendrogram(Z, labels=df.index, leaf_rotation=0, orientation="left", color_threshold=240, above_threshold_color='grey')
#      17
#      18 # Create a color palette with 3 color for the 3 cyl possibilities
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/cluster/hierarchy.py in dendrogram(Z, p, truncate_mode, color_threshold, get_leaves, orientation, labels, count_sort, distance_sort, show_leaf_counts, no_plot, no_labels, leaf_font_size, leaf_rotation, leaf_label_func, show_contracted, link_color_func, ax, above_threshold_color)
#    3275                          "'bottom', or 'right'")
#    3276
# -> 3277     if labels and Z.shape[0] + 1 != len(labels):
# ...

# %% [markdown]
# ## Heatmap

# %%
# Libraries
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
 
# Data set
url = 'https://python-graph-gallery.com/wp-content/uploads/mtcars.csv'
df = pd.read_csv(url)
df = df.set_index('model')
 
# CHange color palette
# sns.clustermap(df, metric="euclidean", standard_scale=1, method="ward", cmap="mako")
sns.clustermap(df, metric="euclidean", standard_scale=1, method="ward", cmap="viridis")
# sns.clustermap(df, metric="euclidean", standard_scale=1, method="ward", cmap="Blues")

# %% [markdown]
# ## Contour Plot

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')
 
# # Basic 2D density plot
# sns.set_style("white")
# sns.kdeplot(df.sepal_width, df.sepal_length)
 
# # Customize it with the same argument as 1D density plot
# sns.kdeplot(df.sepal_width, df.sepal_length, cmap="Reds", shade=True, bw=.15)
 
# Some features are characteristic of 2D: color palette and wether or not color the lowest range
sns.kdeplot(df.sepal_width, df.sepal_length, cmap="Blues", shade=True)#, shade_lowest=True)

# %% [markdown]
# ## TSNE

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# import sample dataset
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.data
y = digits.target

# Fit and transform with TSNE
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)

# Project the data into 2Ds
projected =  tsne.fit_transform(X)

target_ids = range(len(digits.target_names))


# set figure size
figure = {'figsize':[13.0, 10.0]}
matplotlib.rc('figure', **figure)
# Custom color map 
from matplotlib.colors import LinearSegmentedColormap

colors = ['#b00ac4', '#6760dd', '#1db6f6', '#47ceba', '#b2c34e', '#ffaf07', '#ff8420', '#ff5939']

# plot each group as a different color
for i, c, label in zip(target_ids, colors, digits.target_names):
    plt.scatter(projected[y == i, 0], projected[y == i, 1], c=c, label=label,alpha=0.5)

# %% [markdown]
# ## Principal Component Analysis (PCA)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# import sample dataset
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
digits = load_digits()

pca = PCA(2)  # project from 64 to 2 dimensions
projected = pca.fit_transform(digits.data)
target_ids = range(len(digits.target_names))


# set figure size
figure = {'figsize':[13.0, 10.0]}
matplotlib.rc('figure', **figure)

colors = ['#b00ac4', '#6760dd', '#1db6f6', '#47ceba', '#b2c34e', '#ffaf07', '#ff8420', '#ff5939']

# plot each group as a different color
for i, c, label in zip(target_ids, colors, digits.target_names):
    plt.scatter(projected[y == i, 0], projected[y == i, 1], c=c, label=label,alpha=0.5)
plt.xlabel('component 1')
plt.ylabel('component 2')
# Out:
# Text(0, 0.5, 'component 2')

# %% [markdown]
# ## Real Data Examples

# %%
# Bar plot Orf1a screen example
# import required packages (the term library/package mean the same thing and are used interchangably throughout)
import matplotlib # general library for plotting (developed based off of Matlab)
import matplotlib.pyplot as plt 
import pandas as pd # library for data manipulation, allows making dataframe similar to those in R

# set font 
font = {
        'sans-serif':'Arial',
        'size'   : 15,
        'weight' : 'bold'}

plt.rc('font', **font)

# set figure size
figure = {'figsize':[11.0, 6.0]}
plt.rc('figure', **figure)

# set figure color scheme
axes = {'prop_cycle': matplotlib.cycler('color',['#d45087','#ffa600'])}
plt.rc('axes', **axes)

# add caps to errorbars
plt.rcParams.update({'errorbar.capsize': 4})

# data to plot 
orf1a_df = pd.read_csv('Orf1a.csv')
display(orf1a_df) # show the data in a table
# compute standard deviation for each column
errs = orf1a_df.std() # compute standard deviations of each column
means = orf1a_df.mean() # compute means for each column
labels = orf1a_df.columns
labels

# generate colors for bars (a list of colors)
#   bars associated with Orf1a-targeting siRNAs will be colored red if below the threshold (t) 
#   grey otherwise
#   bars associated wiht UNT or NTC will be colored black
#   bars associated with HTT will be colored blue
t= 40 # threshold
colors = []
for l in labels:
    if l.isdigit(): # if label is a number only then is from siRNA targeting Orf1a
        # test if above/below threshold
        if orf1a_df[l].mean() < t:
            colors.append("red")
        else:
            colors.append("grey")
    elif "HTT" in l:
        colors.append("blue")
    else:
        colors.append("black")

# to make error bars go only in one direction
#   Make a list of 0's that goes in front of the errs list:
errs = [[0]*len(errs),errs]

# plot data
plt.figure() 
plt.bar(x=labels,height=means,yerr=errs, # yerr parameter adds error bars
        color=colors, # color by column label
        edgecolor="black", # add black border around bars
       ) 
# rotate x-axis tick labels
#   NOTE: ideally you should not do this but instead make your plot smaller/labels more concise 
#         so they can be read horizontally
plt.xticks(rotation= 45) 

plt.xlabel("siRNA (1.5 μM)",weight="bold") # x-axis labe
plt.ylabel("Relative luciferase expression \n (% of untreated)",weight="bold") # y-axis label (\n indicates a newline character or "enter")
plt.title("Orf1a",pad=20, fontsize = 15,weight="bold") # title
plt.tight_layout() 
# save plot
#   I use .eps format because it is vector based so there will be no resolution issues
#   NOTE: .eps files tend to be larger than other formats
plt.savefig('orf1a_dualglo_screen.eps',bbox_inches="tight",transparent=True)
# Out:
#      416   2290   6059   6322   6499   7643   8200   8201   8744   9679  \
# 0   9.07  39.94  56.49  49.11  95.57  41.17  42.40  39.97  18.90  21.67
# 1  11.39  33.46  58.73  62.46  72.35  40.09  42.28  62.56  23.74  28.12
# 2   8.85  30.93  88.43  46.03  66.17  52.32  52.62  40.68  24.29  36.02
#
#    11594  12932     UNT     NTC  HTT 10150
# 0  51.24  87.52  100.44   98.81      23.49
# 1  56.54  79.28  114.43  105.54      14.21
# 2  71.53  77.71   85.13   97.42      28.11

# %% [markdown]
# ## Scatter Plot with Fitted Curve

# %%
# load in data
# NOTE: added index_col parameter which will set the first column(logarithms of molar concentration) as an index 
#   we want to do this since we won't be using it to take the means
df = pd.read_csv('example_fitting.csv', index_col=0) 
display(df)

y = df.mean(axis=1) # axis=1 will take means row-wise rather than column-wise
err = df.std(axis=1) #standard deviation
x = df.index # the x-axis is the index (since we loaded it in with the index_col=0 (above))

# add caps to errorbars
plt.rcParams.update({'errorbar.capsize': 4})

# log the x values
import math
x = [math.log(x_,10) for x_ in x]




# fit a curve to the data
from scipy.optimize import curve_fit 
# # fit function
def func(x,bottom, top, IC50, slope):
#     return(bottom + ((top-bottom)/(1+np.exp(x-np.log(IC50)))))
    return(bottom + (top-bottom)/(1+10**((np.log(IC50)-x)*slope)))

# convert the x and y data into the correct forms for fitting
xdata = np.array(x)
ydata = np.array(y)#[sum(n) for n in zip(y, err)]) # add the error values to the y values
popt, pcov = curve_fit(func, xdata, ydata,
                       bounds=((0,0,0,-np.inf),(40,np.inf,1,0))
                      )
print("Bottom: ",popt[0])
print("Top: ",popt[1])
print("IC50:",popt[2])
print("HillSlope: ",popt[3])
# # print(pcov)





# # plot data
# plt.figure() 
plt.scatter(x, y,color="green") # code to make the plot
plt.errorbar(x,y,yerr=err,xerr=None,ls='none',ecolor="green")# another way to add error bars

# add curve fit
plt.plot(np.arange(min(x),max(x),0.1), func(np.arange(min(x),max(x),0.1), *popt), color="green")


# add tick marks
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)


plt.xlabel("log (M), siRNA",weight="bold") # x-axis labe
plt.ylabel("target expression \n (% of control)",weight="bold") # y-axis label
# plt.tight_layout()
# Out:
#                  P2 NTC  P2 NTC.1  P2 NTC.2
# log[Agonist], M
# 1.500000e-06       34.5      24.0      19.2
# 7.500000e-07       29.5      51.3      24.7
# 3.750000e-07       15.0      27.8      21.8
# 1.880000e-07       40.7      41.9      28.0
# 9.380000e-08       48.2      46.1      49.0
# 4.690000e-08       62.0      53.3      65.9
# 2.340000e-08       72.5      77.0      77.4
# 1.000000e-09      100.3      95.4     104.2
# Bottom:  26.013678302285683
# Top:  100.37695980995841
# IC50: 0.0006254908734583214
# HillSlope:  -1.2657931068663573
# Text(0, 0.5, 'target expression \n (% of control)')

# %% [markdown]
# <a id='color_schemes'></a>
# # Color Schemes
# A good site to pick color schemes: https://learnui.design/tools/data-color-picker.html#palette
# ### Diverging color Schemes

# %%
import seaborn as sns

import numpy as np
import matplotlib.pyplot as plt
# original SARS-CoV-2 genomic coloring
exn_cols = np.linspace(0, 1, 10)
print(sns.color_palette(plt.cm.tab20b(exn_cols)).as_hex())
sns.palplot(plt.cm.tab20b(exn_cols))
# Out:
# ['#393b79', '#6b6ecf', '#637939', '#b5cf6b', '#8c6d31', '#e7cb94', '#ad494a', '#e7969c', '#a55194', '#de9ed6']

# %%
sns.color_palette("hls", 8)

print(sns.color_palette("hls", 8).as_hex())
make_gradient_color_scheme(12,['#db5f57', '#dbc257', '#91db57', '#57db80', '#57d3db', '#5770db', '#a157db', '#db57b2'])
# Out:
# ['#db5f57', '#dbc257', '#91db57', '#57db80', '#57d3db', '#5770db', '#a157db', '#db57b2']
# ['#db5f57', '#db9857', '#d0c657', '#a5d457', '#7fdb64', '#5edb7b', '#57d7aa', '#57d0db', '#5796db', '#656bdb', '#905ddb', '#b557cd', '#d657b5']
# ['#db5f57',
#  '#db9857',
#  '#d0c657',
#  '#a5d457',
#  '#7fdb64',
#  '#5edb7b',
#  '#57d7aa',
#  '#57d0db',
#  '#5796db',
#  '#656bdb',
#  '#905ddb',
#  '#b557cd',
#  '#d657b5']

# %%
import numpy as np
import matplotlib.pyplot as plt
# original SARS-CoV-2 genomic coloring
exn_cols = (np.linspace(0.1,0.9,10))
print(sns.color_palette(plt.cm.tab20b(exn_cols)).as_hex())
sns.palplot(plt.cm.tab20b(exn_cols))
# Out:
# ['#6b6ecf', '#9c9ede', '#8ca252', '#cedb9c', '#bd9e39', '#e7ba52', '#843c39', '#d6616b', '#7b4173', '#ce6dbd']

# %%
# built-in diverging color scheme
print(sns.color_palette("BrBG",8).as_hex())
sns.palplot(sns.color_palette("BrBG",8).as_hex())
# Out:
# ['#91560d', '#c58e3d', '#e7cf94', '#f6eed9', '#dbefec', '#98d7cd', '#44a299', '#066b63']

# %%
# built-in diverging color scheme
print(sns.color_palette("RdBu_r",8).as_hex())
sns.palplot(sns.color_palette("RdBu_r",8).as_hex())
# Out:
# ['#246aae', '#529dc8', '#a7d0e4', '#e1edf3', '#fae7dc', '#f7b799', '#dc6e57', '#b61f2e']

# %%
# custom diverging color scheme 
print(sns.diverging_palette(255, 133, l=60, n=7).as_hex())
sns.palplot(sns.diverging_palette(255, 133, l=60, n=7).as_hex())
# Out:
# ['#668fe4', '#93b0ec', '#c2d2f4', '#f2f2f2', '#bbdec2', '#80c08e', '#47a35a']

# %%
# custom diverging color scheme - dark center
print(sns.diverging_palette(255, 133, l=60, n=7, center="dark").as_hex())
sns.palplot(sns.diverging_palette(255, 133, l=60, n=7, center="dark").as_hex())
# Out:
# ['#668fe4', '#4f6aa1', '#37435c', '#222222', '#2d4933', '#3a7647', '#47a35a']

# %% [markdown]
# ### Gradient Color Schemes

# %%
def make_gradient_color_scheme(size,color_ls,plot_pal=True):
    '''
    Output list of hex colors for color scheme also displays a plot of the color pallette 
    Inputs:
        size = number of colors in color scheme
        color_ls = list of colors to be used in making gradient
            * can be any length < size
            * if only one color is given other color in gradient will be set to white)
        plot_pal = boolean if True will plot a palplot
    '''
    import numpy as np
    import matplotlib
    import matplotlib.pyplot as plt
    import seaborn as sns
    norm = matplotlib.colors.Normalize(-1,1)
    
    if len(color_ls) == 1:
        color_ls.append("#ffffff")
    grad_cols = [[norm(-1.0), color_ls[0]] ] # first already determined
    if len(color_ls)>len(grad_cols)-1:
        i=1
        while i<len(color_ls)-1: 
            grad_cols.append([norm( i*(2/(len(color_ls)-1))+(-1)), color_ls[i]])
            i+=1
    grad_cols.append([norm(1.0), color_ls[-1]]) # last already determined
    cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", grad_cols)
    hex_cols = []
    for i in range(cmap.N): 
        if i%int(cmap.N/size)==0: # cmp1.N is 256 
            rgb = cmap(i)[:3] # will return rgba, we take only first 3 so we get rgb
            hex_cols.append(matplotlib.colors.rgb2hex(rgb))
    
    if plot_pal:
        sns.palplot(hex_cols)
        print(hex_cols)
    return(hex_cols)

# %%
# Create color scheme from 1 color
heatmap_cols = make_gradient_color_scheme(12,['#3081b0','#afd8f0','white','#ebe467','#f2534e'],True)  

from matplotlib.colors import LinearSegmentedColormap
cm = LinearSegmentedColormap.from_list("custom_cm",heatmap_cols)
# Out:
# ['#3081b0', '#5a9ec5', '#84bada', '#aed7ef', '#c8e4f5', '#e3f1fa', '#fdfeff', '#f9f7d1', '#f2ee9e', '#ece56c', '#edb960', '#ef8a57', '#f25a4f']

# %%
# Create color scheme from 2 colors
make_gradient_color_scheme(9,["#8b41b0",'#0ac49f'])
# Out:
# ['#8b41b0', '#7d4fae', '#6f5eac', '#616caa', '#527ba9', '#4489a7', '#3697a5', '#28a6a3', '#1ab4a1', '#0cc29f']
# ['#8b41b0',
#  '#7d4fae',
#  '#6f5eac',
#  '#616caa',
#  '#527ba9',
#  '#4489a7',
#  '#3697a5',
#  '#28a6a3',
#  '#1ab4a1',
#  '#0cc29f']

# %%
# Create color scheme from 3 colors
make_gradient_color_scheme(10,["#003f5c",'#d45087','#ffa600'])
# Out:
# ['#003f5c', '#2a4264', '#53466d', '#7d4975', '#a64c7e', '#d05086', '#dc5f6f', '#e47055', '#ec813a', '#f59220', '#fda305']
# ['#003f5c',
#  '#2a4264',
#  '#53466d',
#  '#7d4975',
#  '#a64c7e',
#  '#d05086',
#  '#dc5f6f',
#  '#e47055',
#  '#ec813a',
#  '#f59220',
#  '#fda305']

# %%
# Create color scheme from 4 colors
make_gradient_color_scheme(12,["#b00ac4",'#03d5ff','#ffbb00','#ff553b'])
# Out:
# ['#b00ac4', '#853cd3', '#5b6ee1', '#30a0f0', '#05d3fe', '#3ecfc3', '#7dc884', '#bbc245', '#f9bc06', '#ffa40d', '#ff8b1c', '#ff722a', '#ff5939']
# ['#b00ac4',
#  '#853cd3',
#  '#5b6ee1',
#  '#30a0f0',
#  '#05d3fe',
#  '#3ecfc3',
#  '#7dc884',
#  '#bbc245',
#  '#f9bc06',
#  '#ffa40d',
#  '#ff8b1c',
#  '#ff722a',
#  '#ff5939']

# %%
# Create color scheme from 2 colors
make_gradient_color_scheme(4,["#79d9c6",'#7e208a'])
# Out:
# ['#79d9c6', '#7b9bb2', '#7c5e9e', '#7e208a']

# %% [markdown]
# ### Custom Colormap

# %%
# Custom color map 
from matplotlib.colors import LinearSegmentedColormap
cm = LinearSegmentedColormap.from_list("custom_cm",['#b00ac4', '#6760dd', '#1db6f6', '#47ceba', '#b2c34e', '#ffaf07', '#ff8420', '#ff5939'])

# %% [markdown]
# <a id='gene_diagram'></a>
# # Gene Diagram

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib



class GeneImage(object):
    def __init__(self, total_span, exon_intervals, exon_colors=[], marker_pos=[], marker_colors=[], homology_list=[]):
        '''
        **Required Inputs**
        
        total_span
            type: integer
            * length of the gene to be plotted (number of nucleotides)
                Ex: total_span = 4560 # will draw gene of length 4560 nucleotides
                
                NOTE: all exon intervals must be within position 1 to total_span
                NOTE: this script currently only supports two overlapping exons
                
        exon_intervals
            type: 2D list of integers
            * List of start and end positions (in nucleotides) of exons
                Ex: exon_intervals = [[266, 567],[756, 800]] 
                   # will draw two exons: the first starting at position 266 and ending at position 567, the second starting at 756 and ending at position 800
            
            NOTE: put exon intervals in order (from first to last numerically) in this list to prevent issues with coloring properly
            
        **Optional Inputs**
        
        marker_pos
            type: list of integers
            * positions (in nucleotides) of where to put the marker (arrows) within the exon intervals 
            Ex: marker_positions = [874,956,2290] # will place arrows at positions 874,956, and 2290 in the gene diagram
            
            NOTE: marker positions must be within the exon intervals
        
        exon_colors
            type: list of Strings (colors)
            * provide a list of colors to color each exon
            * if no colors are provided will set them automatically
            NOTE: length of exon_colors must equal length of exon_intervals
            
        marker_colors 
            type: list of Strings (colors)
            * To set all marker colors to a single color:
                Set this value to a list of length 1 containing that color
                
                Ex: marker_colors = ["blue"] # will set all marker colors to blue
                
            * To set some markers to a specific color:
                Create a list of colors that is the same length as your list of marker_pos, change the color of
                the value in the list position that corridnates with the marker position.
                
                Ex: marker_colors = ["grey","grey","red","grey","green","red"], marker_pos = [8744,6059,2290,9679,11594,8201] # all markers but the 3rd and 5th marker will be grey, the 3rd marker will be red, the fifth marker will be blue
        
        homologyList
            type: list of integers
            * list of integer values from 0 to 100 indicating the homology to be used for coloring arrows by homology
                A value of 0 indicates 0% homology at that position
                A value of 100 indicates 100% homology at that position
                
            NOTE: length of homology list must be the same as the length for marker_pos 
            
            
        Method modified from: https://gist.github.com/parashardhapola/e095e3ebd068c90e7089b53e46b8e0bc
        Original Author: Parashar Dhapola
        '''
        
        # sort exon_intervals
        exon_intervals.sort()
        
        self.totalSpan = total_span # user input
        self.exonIntervals = exon_intervals # user input
        
        self.markerPositions = marker_pos # optional input
        self.markerColors = marker_colors # optional input 
        self.homologyList = homology_list # optional input
        self.exonColors = exon_colors # optional input
        
        self.exonOverlay = self._find_exon_overlap(self.exonIntervals)
        
        self.markerHeights = []
        self.markerSize = 200
        self.MarkerWeight = 1.5
        self.exonColor = "black"
        self.intronColor = "black"
        self.maxGrad = "#00bfc9"
        self.intronWeight = 0
        self.intronStyle = '-'
        self.barColor= "black"
        self.bgColor = "white"
        self.markerDefaultColor = '#858585'
        self.markerEdgeDefaultColor = "black"
        self.numExons = len(self.exonIntervals)
        self.minExonLen = self.totalSpan*0.005
        self.ylims = {'exon_max': 2, 'exon_min':1}
        self.figure, self.canvas = plt.subplots(figsize=(30,5))
        self.canvas.set_facecolor(self.bgColor)
        self._draw()

    def _set_limits(self):
        self.ylims['intron_max'] = self.ylims['exon_max']*0.25
        self.ylims['intron_min'] = (self.ylims['exon_max'] + self.ylims['exon_min'])/2.0
        self.ylims['bar_min'] = self.ylims['exon_max']-0.6
        self.ylims['bar_max'] = self.ylims['bar_min']+(self.ylims['exon_max']-self.ylims['exon_min'])/5.0
        
    def _find_exon_overlap(self,exon_intervals):
        # takes a SORTED list of exon_intervals and looks for overlapping exons to ensure properly staggered in the diagram
        exon_overlap_ls = [0] # keeps track of overlapping exons, if 0, no overlap, >1 indicates number of overlaps
        exon_overlap_ct = 0
        # start at 2nd exon
        i = 1
        exon_end_pos = exon_intervals[0][-1]
        while i<len(exon_intervals):
            # look for overlap in the exon with the previous exon
            # overlap if this intron's start position is less than the previous intron's end position
            if (exon_intervals[i][0] < exon_end_pos):
                # exons overlap
                exon_overlap_ct+=1
                # new exon_end_pos will be set if this exon ends past previous
                exon_end_pos = max(exon_end_pos,exon_intervals[i][-1])
            else:
                # no overlap
                exon_overlap_ct = 0 # resets the count (in event it increased from previous exons)
                exon_end_pos = exon_intervals[i][-1]
            exon_overlap_ls.append(exon_overlap_ct)
            i+=1

        # Update exon intervals list to accomodate any overlaps
        #    For any overlaps puts largest exon in the back (positions it so largest exon is first in updated_exon_intervals list)
        updated_exon_intervals = []
        i = 0
        while i<len(exon_intervals):
            # check if exon has an overlap (if value is greater than 0 there is an overlap)
            if exon_overlap_ls[i] > 0: 
                # look at previous exon and see if it is larger if so make it first in updated_exon_intervals
                if ((exon_intervals[i-1][0]-exon_intervals[i-1][-1])>(exon_intervals[i][0]-exon_intervals[i][-1])):
                    # swap positions in updated_exon_intervals list:
                    # update previous position to current
                    updated_exon_intervals[-1] = exon_intervals[i]
                    # update current position to previous 
                    updated_exon_intervals.append(exon_intervals[i-1])
                else:
                    updated_exon_intervals.append(exon_intervals[i])
            else:
                updated_exon_intervals.append(exon_intervals[i])
            i+=1
        
        self.exonIntervals = updated_exon_intervals #  updates exon intervals
        return exon_overlap_ls
                
    
    def _transform_spans(self):
        span_lens = [x[1]-x[0] for x in self.exonIntervals]
        max_len = float(max(span_lens))
        transformed_intervals = []
        if max_len < self.minExonLen:
            span_ratios = [x/max_len for x in span_lens]
            expansion_factor = self.totalSpan*1e-11
            for i in range(1,10):
                ef = (2**i)*expansion_factor
                if max_len+ef > self.minExonLen:
                    expansion_factor = ef
                    break
            for i,j in zip(self.exonIntervals, span_ratios):
                mid = (i[0] + i[1])/2
                f = (expansion_factor*j)/2
                if mid+f - mid-f > self.minExonLen:
                    transformed_intervals.append([mid-f, mid+f])
                else:
                    transformed_intervals.append([mid-(self.minExonLen/2), mid+(self.minExonLen/2)])
        else:
            for i in range(self.numExons):
                if span_lens[i] < self.minExonLen:
                    mid = (self.exonIntervals[i][0] + self.exonIntervals[i][0])/2 
                    transformed_intervals.append([mid-(self.minExonLen/2), mid+(self.minExonLen/2)])
                else:
                    transformed_intervals.append(self.exonIntervals[i])
        self.exonIntervals = transformed_intervals[:]
        
    def _draw_exon(self, span,col):
        self.canvas.fill_between(span, self.ylims['exon_min']+.2, self.ylims['exon_max']-.2,
                                 edgecolor=self.bgColor, facecolor=col)
        return True
    
    def _draw_staggered_exon(self, span,col):
        self.canvas.fill_between(span, self.ylims['exon_min']-.1+.2, self.ylims['exon_max']-.1-.2,
                                 edgecolor=self.bgColor, facecolor=col)
        return True
        
    def _draw_intron(self, span):
        mid = (span[0]+span[1])/2.0
        self.canvas.plot([span[0], mid], [self.ylims['intron_min'], self.ylims['intron_max']],
                         c=self.intronColor, lw=self.intronWeight, ls=self.intronStyle)
        self.canvas.plot([mid, span[1]], [self.ylims['intron_max'], self.ylims['intron_min']],
                         c=self.intronColor, lw=self.intronWeight, ls=self.intronStyle)
        return True
    
    def _draw_markers(self):
        if self.markerHeights == []:
            self.markerHeights = [self.ylims['exon_max']-self.ylims['exon_min'] for x in self.markerPositions]
        if self.markerColors == []:
            self.markerColors = [self.markerDefaultColor for x in self.markerPositions]
        if self.homologyList == []:
            cmp1 = matplotlib.colors.LinearSegmentedColormap.from_list("", self.markerColors)
            self.canvas.scatter(self.markerPositions, [x+0.84 for x in self.markerHeights], 
                c = self.markerColors,
                s=self.markerSize, marker='v', cmap=cmp1,
                linewidths=1,edgecolors=self.markerEdgeDefaultColor, alpha=1)
        else:
            # If user inputs a list of homology values then will color arrows by homology with a color gradient
            norm = matplotlib.colors.Normalize(-1,1)
            grad_colrs = [[norm(-1.0), "white"],[norm( 1.0), self.maxGrad]]
            cmp1 = matplotlib.colors.LinearSegmentedColormap.from_list("", grad_colrs)
            # NOTE: 0.84 was an arbitrary number selected to ensure arrow labels show up at correct point on Exon bars
            self.canvas.scatter(self.markerPositions, [x+0.84 for x in self.markerHeights], 
                    # homology list
                    c = self.homologyList,
                    s=self.markerSize, marker='v', cmap=cmp1,
                    linewidths=1,edgecolors=self.markerEdgeDefaultColor, alpha=1)
    
    def _clean_axes(self):
        self.canvas.set_yticks([], [])
        self.canvas.get_xaxis().tick_top()
        self.canvas.tick_params(axis='x', direction='out')
        self.canvas.set_xticks([])
        for o in ["top", "bottom", "left", "right"]:
            self.canvas.spines[o].set_visible(False)
        min_pos = 0
        if min_pos < 0:
            min_pos = 0
        max_pos = self.totalSpan#int(self.exonIntervals[-1][1] + self.totalSpan * 0.1)
        minortick_pos = [int(x) for x in range(0, self.totalSpan, int((0-self.totalSpan)/20))][1:]
        
    def _draw(self):
        self._set_limits()
        self._transform_spans()
        
        # exon colors
        # if user provided list of exon colors will use them if they are the correct length
        if(self.exonColors == []):
            exn_cols = plt.cm.tab20b(np.linspace(0.1,0.9,len(self.exonIntervals)+1)) 
        elif(len(self.exonColors)<len(self.exonIntervals)):
            print("WARNING: not enough exon colors chosen will use default exon coloring")
            exn_cols = plt.cm.tab20b(np.linspace(0.1,0.9,len(self.exonIntervals)+1)) 
        else:
            exn_cols = self.exonColors
        self.canvas.fill_between([0,self.totalSpan ],
                                  self.ylims['bar_min'], self.ylims['bar_max'],
                                  edgecolor=self.bgColor, facecolor=self.barColor)

    
        for i in range(self.numExons):
            # draw introns
            if i > 0: 
                self._draw_intron([self.exonIntervals[i-1][1], self.exonIntervals[i][0]])
            # draw exons
            # check if exons overlap for this interval
            if self.exonOverlay[i] > 0:
                self._draw_staggered_exon(self.exonIntervals[i],exn_cols[i])
            else:
                self._draw_exon(self.exonIntervals[i],exn_cols[i])
        
        if(self.markerPositions != []):
            self._draw_markers()
        self._clean_axes()
    
    def show(self):
        plt.show()
        
    def save(self,file_name):
        plt.savefig(file_name+".eps", format='eps',transparent=True)
        print("File saved to: ",file_name+".eps" )

# %%
# Create color scheme from 2 colors
make_gradient_color_scheme(9,["#79d9c6",'#74407a']) 

# Create color scheme from 3 colors
make_gradient_color_scheme(9,['#ffa600',"#79d9c6","#003f5c",'#d45087','#ffa600'])
# Out:
# ['#79d9c6', '#78c8be', '#78b7b5', '#77a7ad', '#7796a5', '#76859c', '#767494', '#75638c', '#755383', '#74427b']
# ['#ffa600', '#c4bc57', '#89d3ae', '#53a8a4', '#1d6476', '#2a4264', '#874a77', '#d7567d', '#ea7c42', '#fda206']

# %%
# Patient isolate homology:
# homology_list =  [20, 18, 17, 20, 12, 11, 23, 37, 13, 26, 14, 11, 23, 12, 13, 24, 12, 16, 13, 49, 14, 15, 9, 15, 13, 18, 17, 20, 16, 77, 16, 21, 16, 7, 14, 15, 17, 31, 30, 31, 17, 32, 31, 31, 13, 34, 36, 18, 8, 11, 9, 8, 8, 14, 24, 7, 13, 9, 14, 12, 13, 36, 100, 13, 18, 13, 15, 94, 14, 13, 41, 14, 48, 41, 47, 46, 46, 43, 36, 41, 6, 43, 43, 40, 16, 21, 21, 13, 21, 169, 20, 13, 22, 169, 17, 19, 14, 11, 14, 20, 19, 31, 12, 21, 17, 6, 21, 25]

# CoV family homology:
# homology_list = [3,3,4,3,16,64,42,35,59,14,4,64,78,5,42,4,38,68,58,19,43,67,68,69,24,6,60,70,40,7,17,25,8,5,66,54,9,63,10,9,38,47,49,10,28,15,34,9,12,11,12,24,64,100,34,13,63,63,49,51,47,77,64,66,51,50,31,9,55,15,11,10,34,10,34,12,11,56,37,21,11,53,84,14,13,12,87,10,15,10,12,9,9,12,13,22,42,67,10,10,29,30,5,4,13,15,22,0
# NOTE: NEED TO UPDATE c IN CODE ABOVE TO CHANGE HOMOLOGY COLORS IN ARROWS!!

# marker positions


 


gene = GeneImage(total_span=31976,
                 exon_intervals=[[266, 21555],[266, 13483], [21563, 25384], [25393, 26220], [26245, 26472], [26523, 27191], [27394, 27759], [27894, 28259], [28274, 29533]],
                 exon_colors=['#ffa600', '#c4bc57', '#89d3ae', '#53a8a4', '#1d6476', '#2a4264', '#874a77', '#d7567d', '#ea7c42', '#fda206'],
                 #['#79d9c6', '#51a6a3', '#297480', '#01415d', '#43446a', '#894a78', '#cf5086', '#e16a5e', '#ef8731', '#fda305'],
                 marker_pos=[25992,25870,25734,25852,25773,25688,25413,25570,25868,25717,27483,27598,27466,27455,27595,27671,27464,27445,27461,27481,28119,28218,27932,27940,28002,28222,28128,28219,27970,28127,26374,26261,26269,26277,26369,26260,26284,26305,26265,26321,26581,27014,26717,26638,26656,27123,26573,26693,26570,26572,29328,29307,28945,29464,29293,28992,29276,29292,29327,29303,14361,17193,19120,15376,21391,13878,17980,18571,17034,17284,7249,8744,9679,11197,6322,12515,2290,9041,5238,2969,24056,23698,24635,23774,24473,23239,23240,24828,24254,23936],
                )
# save file
gene.save("sars-cov-2_siRNAs_new")
# Out:
# File saved to:  sars-cov-2_siRNAs_new.eps

# %% [markdown]
# ## Example 1:
# * minimal required inputs

# %%
gene = GeneImage(total_span=1000,
                 exon_intervals=[[100,160],[200,400],[500,576],[600,950]],
                )
# save file
gene.save("gene_minimal")
# Out:
# File saved to:  gene_minimal.eps

# %% [markdown]
# ## Example 2:
# * position markers

# %%
# PTEN (NM_001304717)
gene = GeneImage(total_span=1000,
                 exon_intervals=[[100,160],[200,400],[500,576],[600,950]],
                 marker_pos = [135,156,224,356,342,505,675,689,765,793,902,946],
                )
# save file
gene.save("gene_with_markers")
# Out:
# File saved to:  gene_with_markers.eps

# %% [markdown]
# ## Example 3:
# * position markers with custom colors

# %%
gene = GeneImage(total_span=1000,
                 exon_intervals=[[100,160],[200,400],[500,576],[600,950]],
                 marker_pos = [135,156,224,356,342,505,675,689,765,793,902,946],
                 marker_colors = ['cyan','grey', 'grey', 'grey','magenta', 'grey', 'grey', 'grey', 'cyan','grey', 'grey','lime'],
                )

# save file
gene.save("gene_with_colored_markers")
# Out:
# File saved to:  gene_with_colored_markers.eps

# %% [markdown]
# ## Example 4:
# * custom exon colors

# %%
gene = GeneImage(total_span=1000,
                 exon_intervals=[[100,160],[200,400],[500,576],[600,950]],
                 exon_colors = ['#00e8ba', '#20b6ae', '#3f84a2', '#5f5196'],
                 marker_pos = [135,156,224,356,342,505,675,689,765,793,902,946],
                )
# save file
gene.save("gene_with_custom_exon_colors")
# Out:
# File saved to:  gene_with_custom_exon_colors.eps

# %% [markdown]
# ## Example 5:
# * real gene
# * markers indicate siRNA target positions that target mouse

# %%
# PTEN (NM_001304717)
gene = GeneImage(total_span=abs(87863625-87971930), 
                 exon_intervals=[[1,924],[30401,30485],[61889,61933],[67422,67465],[69389,69627],[88494,88635],[94229,94395],[97270,97494],[101663,108306]],
                 marker_pos = [103117, 105933, 106169, 103796, 107565, 103795, 104223, 108104, 107051, 105724, 103060, 101676, 61904, 94386, 102034, 104216, 101677, 61905, 105120],
                 marker_colors = ['grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey',
                                  'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red'
                                 ], # color those that target mouse
                )
# save file
gene.save("PTEN_gene_colored_markers")
# Out:
# File saved to:  PTEN_gene_colored_markers.eps

# %% [markdown]
# ## Example 6:
# * Viral Genome
# * position markers
# * custom exon (gene) colors

# %%
# MERS genome* (Accession: KT029139)
gene = GeneImage(total_span=30108, 
                 # *NOTE: this is missing exons [25852,26181] and [25532,25843], and exon [21516,25517] is actually [21456,25517]
                 exon_intervals=[[279,21514],[279,13454],[21516,25517],[26093,26833],[26840,27514],[27590,27838],[27853,28512],[28566,29807]], 
                 exon_colors=['#003f5c','#4a839e','#665191','#a05195','#d45087','#f95d6a','#ff7c43','#ffa600'],
                 marker_pos=[416, 6322, 8200, 9679, 14080, 15376, 17370, 20497, 21944, 22820, 23239, 24056, 25413, 26277, 26369, 26463, 26573, 26624, 26693, 27032, 27455, 27656, 27715, 27932, 28002, 28119, 28163, 28407, 28992, 29292, 29307],
                )
# save file
gene.save("mers-cov_genome")
# Out:
# File saved to:  mers-cov_genome.eps

# %% [markdown]
# ## Example 7:
# * Viral Genome
# * position markers
# * custom exon (gene) colors
# * position markers colored by homology

# %%
# MERS genome* (Accession: KT029139)
gene = GeneImage(total_span=30108, 
                 # *NOTE: this is missing exons [25852,26181] and [25532,25843], and exon [21516,25517] is actually [21456,25517]
                 exon_intervals=[[279,21514],[279,13454],[21516,25517],[26093,26833],[26840,27514],[27590,27838],[27853,28512],[28566,29807]], 
                 exon_colors=['#003f5c','#4a839e','#665191','#a05195','#d45087','#f95d6a','#ff7c43','#ffa600'],
                 marker_pos=[416, 6322, 8200, 9679, 14080, 15376, 17370, 20497, 21944, 22820, 23239, 24056, 25413, 26277, 26369, 26463, 26573, 26624, 26693, 27032, 27455, 27656, 27715, 27932, 28002, 28119, 28163, 28407, 28992, 29292, 29307],
                 # homology_list: list of integers with values from 0 to 100 with 100 being highest homology 0 being no homology
                 homology_list = [97, 27, 70, 28, 39, 93, 77, 27, 49, 59, 19, 8, 9, 25, 50, 98, 62, 36, 79, 84, 71, 66, 1, 34, 71, 69, 1, 94, 40, 37, 81],
                )
# save file
gene.save("mers-cov_genome_colored_by_homology")
# Out:
# File saved to:  mers-cov_genome_colored_by_homology.eps

# %% [markdown]
# <a id='int_plts'></a>
# # Interactive Plots

# %% [markdown]
# <a id='d3'></a>
# ## D3
#
# ### Simple Circles Example

# %%
from IPython.display import display, Javascript, HTML
import json

# %%
from IPython.core.display import HTML
# Get the D3 host remotely 
HTML('<script src="https://d3js.org/d3.v5.min.js"></script>')
# Out:
# <script src="https://d3js.org/d3.v5.min.js"></script>

# %%
# %%HTML
# <div id="observablehq-4b2cebed"></div>
# <script type="module">
# import {Runtime, Inspector} from "https://cdn.jsdelivr.net/npm/@observablehq/runtime@4/dist/runtime.js";
# import define from "https://api.observablehq.com/@d3/zoomable-icicle.js?v=3";
# const inspect = Inspector.into("#observablehq-4b2cebed");
# (new Runtime).module(define, name => name === "chart" ? inspect() : undefined);
# </script>
# Out:
# <div id="observablehq-4b2cebed"></div>
# <script type="module">
# import {Runtime, Inspector} from "https://cdn.jsdelivr.net/npm/@observablehq/runtime@4/dist/runtime.js";
# import define from "https://api.observablehq.com/@d3/zoomable-icicle.js?v=3";
# const inspect = Inspector.into("#observablehq-4b2cebed");
# (new Runtime).module(define, name => name === "chart" ? inspect() : undefined);
# </script>

# %%
# %%HTML
# <div id="observablehq-19e2afc5" style="width:1000px"></div>
# <script type="module">
# import {Runtime, Inspector} from "https://cdn.jsdelivr.net/npm/@observablehq/runtime@4/dist/runtime.js";
# import define from "https://api.observablehq.com/@mbostock/hello-cola.js?v=3";
# const inspect = Inspector.into("#observablehq-19e2afc5");
# (new Runtime).module(define, name => name === "chart" ? inspect() : undefined);
# </script>
# Out:
# <div id="observablehq-19e2afc5" style="width:1000px"></div>
# <script type="module">
# import {Runtime, Inspector} from "https://cdn.jsdelivr.net/npm/@observablehq/runtime@4/dist/runtime.js";
# import define from "https://api.observablehq.com/@mbostock/hello-cola.js?v=3";
# const inspect = Inspector.into("#observablehq-19e2afc5");
# (new Runtime).module(define, name => name === "chart" ? inspect() : undefined);
# </script>

# %%
# %%HTML
# <div id="observablehq-6a952e31"></div>
# <script type="module">
# import {Runtime, Inspector} from "https://cdn.jsdelivr.net/npm/@observablehq/runtime@4/dist/runtime.js";
# import define from "https://api.observablehq.com/@d3/zoomable-sunburst.js?v=3";
# const inspect = Inspector.into("#observablehq-6a952e31");
# (new Runtime).module(define, name => name === "chart" ? inspect() : undefined);
# </script>
# Out:
# <div id="observablehq-6a952e31"></div>
# <script type="module">
# import {Runtime, Inspector} from "https://cdn.jsdelivr.net/npm/@observablehq/runtime@4/dist/runtime.js";
# import define from "https://api.observablehq.com/@d3/zoomable-sunburst.js?v=3";
# const inspect = Inspector.into("#observablehq-6a952e31");
# (new Runtime).module(define, name => name === "chart" ? inspect() : undefined);
# </script>

# %% [markdown]
# <a id='Tableau'></a>
# ## Tableau

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1589982219050' style='position: relative'><noscript>
# <a href='#'>
# <img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ho&#47;HowHappyAreWe_15891520173890&#47;HowHappyAreWe&#47;1_rss.png' style='border: none' />
# </a></noscript><object class='tableauViz'  style='display:none;'>
# <param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' />
# <param name='embed_code_version' value='3' />
# <param name='site_root' value='' /><param name='name' value='HowHappyAreWe_15891520173890&#47;HowHappyAreWe' />
# <param name='tabs' value='no' /><param name='toolbar' value='yes' />
# <param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ho&#47;HowHappyAreWe_15891520173890&#47;HowHappyAreWe&#47;1.png' />
# <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' />
# <param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' />
# <param name='display_count' value='yes' /><param name='filter' value='mobile=' /></object></div>
# <script type='text/javascript'>
# var divElement = document.getElementById('viz1589982219050');
# var vizElement = divElement.getElementsByTagName('object')[0];
# vizElement.style.width='1400px';vizElement.style.height='1227px';
# var scriptElement = document.createElement('script');
# scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';
# vizElement.parentNode.insertBefore(scriptElement, vizElement);
# </script>
# Out:
# <div class='tableauPlaceholder' id='viz1589982219050' style='position: relative'><noscript>
# <a href='#'>
# <img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ho&#47;HowHappyAreWe_15891520173890&#47;HowHappyAreWe&#47;1_rss.png' style='border: none' />
# </a></noscript><object class='tableauViz'  style='display:none;'>
# <param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' />
# <param name='embed_code_version' value='3' />
# <param name='site_root' value='' /><param name='name' value='HowHappyAreWe_15891520173890&#47;HowHappyAreWe' />
# <param name='tabs' value='no' /><param name='toolbar' value='yes' />
# <param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ho&#47;HowHappyAreWe_15891520173890&#47;HowHappyAreWe&#47;1.png' />
# <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' />
# ...

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1589982067968' style='position: relative'>
# <noscript><a href='#'>
# <img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;CO&#47;COVID19_15844962693420&#47;COVID19-TrendTracker&#47;1_rss.png' style='border: none' />
# </a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' />
# <param name='site_root' value='' />
# <param name='name' value='COVID19_15844962693420&#47;COVID19-TrendTracker' />
# <param name='tabs' value='yes' />
# <param name='toolbar' value='yes' />
# <param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;CO&#47;COVID19_15844962693420&#47;COVID19-TrendTracker&#47;1.png' /> <param name='animate_transition' value='yes' />
# <param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' />
# <param name='display_overlay' value='yes' /><param name='display_count' value='yes' />
# </object></div>                <script type='text/javascript'>
# var divElement = document.getElementById('viz1589982067968');
# var vizElement = divElement.getElementsByTagName('object')[0];
# if ( divElement.offsetWidth > 800 )
# { vizElement.style.width='1366px';vizElement.style.height='818px';}
# else if ( divElement.offsetWidth > 500 )
# { vizElement.style.width='1366px';vizElement.style.height='818px';}
# else { vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*1.77)+'px';}
# var scriptElement = document.createElement('script');
# scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';
# vizElement.parentNode.insertBefore(scriptElement, vizElement);
# </script>
# Out:
# <div class='tableauPlaceholder' id='viz1589982067968' style='position: relative'>
# <noscript><a href='#'>
# <img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;CO&#47;COVID19_15844962693420&#47;COVID19-TrendTracker&#47;1_rss.png' style='border: none' />
# </a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' />
# <param name='site_root' value='' />
# <param name='name' value='COVID19_15844962693420&#47;COVID19-TrendTracker' />
# <param name='tabs' value='yes' />
# <param name='toolbar' value='yes' />
# <param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;CO&#47;COVID19_15844962693420&#47;COVID19-TrendTracker&#47;1.png' /> <param name='animate_transition' value='yes' />
# <param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' />
# ...

# %% [markdown]
# <a id='etc'></a>
# # Additional Useful Methods

# %% [markdown]
# ### Convert siRNA target positions to Genomic Positions

# %%
def get_genomic_positions(exon_intervals,marker_pos):
    ''' 
    Converts siRNA target positions to genomic positions
    
    Inputs:
        exon_intervals 
            list of exon intervals (2D list of integers)
        marker_pos
            list of marker positions (list of integers)
    '''
    coding_intervals = [[1,abs(exon_intervals[0][0]-exon_intervals[0][-1])]] # add first exon 
    for e in exon_intervals[1:]: # skip first exon
        diff = abs(e[0]-e[-1])
        coding_intervals.append([coding_intervals[-1][-1]+1,diff+(coding_intervals[-1][-1]+1)])


    # for each marker position, determines which exon it belongs to then adds the appropriate distance in genomic DNA sequence
    genomic_marker_pos = []
    for m in marker_pos:
        i=0
        while i<len(coding_intervals):
            if (m>=coding_intervals[i][0] and m<=coding_intervals[i][-1]):
                # it is in this exon
                genomic_marker_pos.append(exon_intervals[i][0]-coding_intervals[i][0]+m)
                i=len(coding_intervals)
            i+=1

    if (len(genomic_marker_pos ) != len(msarker_pos)):
        print("ERROR: there was an issue converting genomic and marker positions")
    
    print("Genomic marker positions:")
    print(genomic_marker_pos)

get_genomic_positions(exon_intervals=[[1,924],[30401,30485],[61889,61933],[67422,67465],[69389,69627],[88494,88635],[94229,94395],[97270,97494],[101663,108306]],
                      marker_pos = [3325, 6141, 6377, 4004, 7773, 4003, 4431, 8312, 7259, 5932, 3268, 1884, 1024, 1636, 2242, 4424, 1885, 1025, 5328]
                     )

# %% [markdown]
# [Return to Top of Page](#top)
